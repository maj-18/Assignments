# %% [markdown]
# # Assignment 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading the dataset

# %%
iris_data = pd.read_csv('iris.csv')
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Columns in the dataset

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Column info

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Mean of each column

# %%
iris_data.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Null values in the dataset

# %%
iris_data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
iris_data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Species Count

# %%
iris_data['Classification'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %%
plt.title('Species Count',fontsize=25)
sns.countplot(iris_data['Classification'])
# Out:
# <AxesSubplot:title={'center':'Species Count'}, xlabel='Classification', ylabel='count'>

# %% [markdown]
# # Comparison of sepal width and length

# %%
plt.figure(figsize=(15,8))
plt.title('Comparison between various species based on sepal length and width',fontsize=25)
sns.scatterplot(iris_data['SL'],iris_data['SW'],hue =iris_data['Classification'],s=50)
# Out:
# <AxesSubplot:title={'center':'Comparison between various species based on sepal length and width'}, xlabel='SL', ylabel='SW'>

# %% [markdown]
# # Comparison of petal length and width

# %%
plt.figure(figsize=(15,8))
plt.title('Comparison between various species based on petal length and width',fontsize=25)
sns.scatterplot(iris_data['PL'], iris_data['PW'], hue = iris_data['Classification'], s= 50)
# Out:
# <AxesSubplot:title={'center':'Comparison between various species based on petal length and width'}, xlabel='PL', ylabel='PW'>

# %% [markdown]
# # Checking Correlation

# %%
plt.figure(figsize=(10,11))
sns.heatmap(iris_data.corr(),annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# # Pairplots

# %%
sns.pairplot(iris_data,hue="Classification",height=4)
